# %% [markdown]
# Ejercicio 1.

# %%
#Definimos la función
x=[]  #inicializamos a x

def calcular_idn(X):
    n = len(X)

# calcular min y max
    minimo = min(X)
    maximo = max(X)
 #Estandarización min-max usando for
    Z = []
    for x in X:
        z = (x - minimo) / (maximo - minimo)
        Z.append(z)

#Promedio de Z
    suma = 0
    for z in Z:
        suma += z
    prom = suma / n

#Calcular IDN
    suma_cuadrados = 0
    for z in Z:
        suma_cuadrados += (z - prom) ** 2
    idn = suma_cuadrados / n

    return idn


# Vector
X = [12.4, 8.1, 15.7, 9.3, 14.8, 10.2, 11.6]

# Calcular IDN
resultado = calcular_idn(X)
print(resultado)
# Out:
# 0.11642828876703037

# %%
resultado
# Out:
# 0.11642828876703037

# %% [markdown]
# Ejercio 2

# %% [markdown]
# Ejercicio 2.
# Se tiene la siguiente relación entre las variables
# x,y y z.

# %%
#crear una malla
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

# Crear malla
x = np.linspace(-10, 10, 500)
y = np.linspace(-10, 10, 500)
X, Y = np.meshgrid(x, y)
A = X + Y  # x + y sobre toda la malla

# Inicializar matriz z
z = np.zeros_like(A)

# Condición: x + y <= 1/2 → z = 20
region_1 = A <= 1/2
z[region_1] = 20

# Resto: aplicar la fórmula para z
region_2 = ~region_1
z[region_2] = np.exp(np.exp(np.cos(A[region_2])) - 2 * np.arctan(np.sin(A[region_2])))

# Graficar la función
plt.figure(figsize=(8, 6))
plt.imshow(z, extent=[-10, 10, -10, 10], origin='lower', cmap='viridis', aspect='auto')
plt.colorbar(label='f(x,y)')
plt.title(r'Visualización de $f(x,y)$ definida por partes')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.grid(False)
plt.show()

# %% [markdown]
# Utilice los datos de los nacimientos por estado del 2020 al 2022 del repositorio en Github y realice lo siguiente:

# %% [markdown]
# a) Obtenga un Dataframe que tenga como columnas el número de nacimientos de mujeres, el número de nacimientos de hombres y el número total de nacimientos por año durante el 2020 al 2022. Obtenga una gráfica de cada categoría.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

ruta1='https://raw.githubusercontent.com/jamc88/AD-MCMAI/refs/heads/main/Datos/nacimientos_2020.csv'
datos1=pd.read_csv(ruta1,index_col='Estado')

ruta2='https://raw.githubusercontent.com/jamc88/AD-MCMAI/refs/heads/main/Datos/nacimientos_2021.csv'
datos2=pd.read_csv(ruta2,index_col='Estado')

ruta3='https://raw.githubusercontent.com/jamc88/AD-MCMAI/refs/heads/main/Datos/nacimientos_2022.csv'
datos3=pd.read_csv(ruta3,index_col='Estado')

# %%
datos1
# Out:
#                      Abreviatura    Regiones  Mujeres  Hombres  No_esp   Total
# Estado
# Aguascalientes                AG     Noreste     9966    10404       0   20370
# Baja California               BC    Noroeste    23539    24406       0   47945
# Baja California Sur           BS    Noroeste     4982     5099       0   10081
# Campeche                      CM     Sureste     5275     5454       0   10729
# Coahuila de Zaragoza          CO     Noreste    22594    23221       0   45815
# Colima                        CL   Occidente     4325     4623       0    8948
# Chiapas                       CS     Sureste    47962    50136       0   98098
# Chihuahua                     CH    Noroeste    23436    24659       0   48095
# CDMX                          CX  Centro-Sur    32218    33485       0   65703
# Durango                       DG    Noroeste    13713    14275       0   27988
# Guanajuato                    GT     Noreste    41979    43278       2   85259
# ...

# %%
datos20_22=pd.concat([datos1,datos2,datos3])

# %%
datos20_22
# Out:
#                      Abreviatura    Regiones  Mujeres  Hombres  No_esp   Total
# Estado
# Aguascalientes                AG     Noreste     9966    10404       0   20370
# Baja California               BC    Noroeste    23539    24406       0   47945
# Baja California Sur           BS    Noroeste     4982     5099       0   10081
# Campeche                      CM     Sureste     5275     5454       0   10729
# Coahuila de Zaragoza          CO     Noreste    22594    23221       0   45815
# ...                          ...         ...      ...      ...     ...     ...
# Tamaulipas                    TM     Noreste    23177    24110       0   47287
# Tlaxcala                      TL  Centro-Sur     9653     9964       1   19618
# Veracruz                      VE     Sureste    53782    55329       0  109111
# Yucatan                       YU     Sureste    13829    14103       0   27932
# Zacatecas                     ZA     Noreste    13368    13402       0   26770
#
# ...

# %%
plt.figure(figsize=(6, 10), dpi=150)
plt.barh(datos20_22.index, datos20_22['Hombres'], color = 'blue', alpha=0.6)
plt.title('Número de nacimientos hombres (2020-2022) ')
plt.ylabel('Estados')
plt.xlabel('Número de nacimientos')
plt.show()

# %%
plt.figure(figsize=(6, 10), dpi=150)
plt.barh(datos20_22.index, datos20_22['Mujeres'], color = 'pink', alpha=0.6)
plt.title('Número de nacimientos mujeres (2020-2022) ')
plt.ylabel('Estados')
plt.xlabel('Mujeres')
plt.show()

# %%
datos20_22['Total']=datos20_22['Hombres']+datos20_22['Mujeres']

# %%
plt.figure(figsize=(6, 10), dpi=150)
plt.barh(datos20_22.index, datos20_22['Total'], color = 'brown', alpha=0.6)
plt.title('Número de nacimientos totales (2020-2022) ')
plt.ylabel('Estados')
plt.xlabel('Total de nacimientos')
plt.show()

# %% [markdown]
# b) Agregue a los datos de nacimientos del 2020 la columna de población por estado y la tasa de nacimientos por cada mil habitantes. Gráfique la tasa de nacimientos por estado.

# %%
ruta='https://raw.githubusercontent.com/jamc88/AD-MCMAI/refs/heads/main/Datos/nacimientos_2020.csv'
datos1=pd.read_csv(ruta,index_col='Estado')
datos1.head()
# Out:
#                      Abreviatura  Regiones  Mujeres  Hombres  No_esp  Total
# Estado
# Aguascalientes                AG   Noreste     9966    10404       0  20370
# Baja California               BC  Noroeste    23539    24406       0  47945
# Baja California Sur           BS  Noroeste     4982     5099       0  10081
# Campeche                      CM   Sureste     5275     5454       0  10729
# Coahuila de Zaragoza          CO   Noreste    22594    23221       0  45815

# %%
ruta_poblacion = 'https://raw.githubusercontent.com/jamc88/AD-MCMAI/refs/heads/main/Datos/poblacion.csv'
df_poblacion = pd.read_csv(ruta_poblacion,index_col='Estado')
df_poblacion.head()
# Out:
#                       Regiones  H_1990  M_1990   H_2000   M_2000   H_2010  \
# Estado
# Aguascalientes         Noreste  350218  369441   456533   487752   576638
# Baja California       Noroeste  832090  828765  1252581  1234786  1591610
# Baja California Sur   Noroeste  161833  155931   216250   207791   325433
# Campeche               Sureste  268772  266413   344334   346355   407721
# Coahuila de Zaragoza   Noreste  979097  993243  1140195  1157875  1364197
#
#                        M_2010   H_2020   M_2020
# Estado
# Aguascalientes         608358   696683   728924
# Baja California       1563460  1900589  1868431
# Baja California Sur    311593   405879   392568
# Campeche               414720   456939   471424
# Coahuila de Zaragoza  1384194  1563669  1583102

# %%
datos1['Poblacion']=df_poblacion['H_2020']+df_poblacion['M_2020']
datos1.head()
# Out:
#                      Abreviatura  Regiones  Mujeres  Hombres  No_esp  Total  \
# Estado
# Aguascalientes                AG   Noreste     9966    10404       0  20370
# Baja California               BC  Noroeste    23539    24406       0  47945
# Baja California Sur           BS  Noroeste     4982     5099       0  10081
# Campeche                      CM   Sureste     5275     5454       0  10729
# Coahuila de Zaragoza          CO   Noreste    22594    23221       0  45815
#
#                       Poblacion
# Estado
# Aguascalientes          1425607
# Baja California         3769020
# Baja California Sur      798447
# Campeche                 928363
# Coahuila de Zaragoza    3146771

# %%
datos1['Poblacion']=df_poblacion['H_2020']+df_poblacion['M_2020']
datos1.head()
# Out:
#                      Abreviatura  Regiones  Mujeres  Hombres  No_esp  Total  \
# Estado
# Aguascalientes                AG   Noreste     9966    10404       0  20370
# Baja California               BC  Noroeste    23539    24406       0  47945
# Baja California Sur           BS  Noroeste     4982     5099       0  10081
# Campeche                      CM   Sureste     5275     5454       0  10729
# Coahuila de Zaragoza          CO   Noreste    22594    23221       0  45815
#
#                       Poblacion
# Estado
# Aguascalientes          1425607
# Baja California         3769020
# Baja California Sur      798447
# Campeche                 928363
# Coahuila de Zaragoza    3146771

# %%
#la tasa de nacimientos por cada mil habitantes
datos1['Tasa']=datos1['Total']/datos1['Poblacion']*1000
datos1.head()
# Out:
#                      Abreviatura  Regiones  Mujeres  Hombres  No_esp  Total  \
# Estado
# Aguascalientes                AG   Noreste     9966    10404       0  20370
# Baja California               BC  Noroeste    23539    24406       0  47945
# Baja California Sur           BS  Noroeste     4982     5099       0  10081
# Campeche                      CM   Sureste     5275     5454       0  10729
# Coahuila de Zaragoza          CO   Noreste    22594    23221       0  45815
#
#                       Poblacion       Tasa
# Estado
# Aguascalientes          1425607  14.288650
# Baja California         3769020  12.720813
# Baja California Sur      798447  12.625760
# Campeche                 928363  11.556902
# Coahuila de Zaragoza    3146771  14.559369

# %%
plt.figure(figsize=(6, 10), dpi=150)
plt.barh(datos1.index, datos1['Tasa'], color = 'red', alpha=0.6)
plt.title('Tasa de nacimiento por estado')
plt.ylabel('Estado')
plt.xlabel('Tasa (1000)')
plt.show()

# %% [markdown]
# Ejercicio 4. a) Agregue la columna correspondiente a la serie de **retornos simples** (utilice la función *.pct_change()*) y elimine la primera fila del *DataFrame*.

# %%
ruta='https://raw.githubusercontent.com/jamc88/AD-MCMAI/refs/heads/main/Datos/tesla.csv'
df=pd.read_csv(ruta)
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close
# 0  2020-01-02  28.299999  28.713333  28.114000  28.684000  28.684000
# 1  2020-01-03  29.366667  30.266666  29.128000  29.534000  29.534000
# 2  2020-01-06  29.364668  30.104000  29.333332  30.102667  30.102667
# 3  2020-01-07  30.760000  31.441999  30.224001  31.270666  31.270666
# 4  2020-01-08  31.580000  33.232666  31.215334  32.809334  32.809334

# %%
#a) Agregue la columna correspondiente a la serie de retornos simples (utilice la función .pct_change()) y elimine la primera fila del DataFrame.
df = df.set_index('Date')
df['Retornos simples']=df['Close'].pct_change()
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close  \
# Date
# 2020-01-02  28.299999  28.713333  28.114000  28.684000  28.684000
# 2020-01-03  29.366667  30.266666  29.128000  29.534000  29.534000
# 2020-01-06  29.364668  30.104000  29.333332  30.102667  30.102667
# 2020-01-07  30.760000  31.441999  30.224001  31.270666  31.270666
# 2020-01-08  31.580000  33.232666  31.215334  32.809334  32.809334
#
#             Retornos simples
# Date
# 2020-01-02               NaN
# 2020-01-03          0.029633
# 2020-01-06          0.019255
# 2020-01-07          0.038801
# 2020-01-08          0.049205

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 756 entries, 2020-01-02 to 2022-12-30
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Open              756 non-null    float64
#  1   High              756 non-null    float64
#  2   Low               756 non-null    float64
#  3   Close             756 non-null    float64
#  4   Adj Close         756 non-null    float64
#  5   Retornos simples  755 non-null    float64
# dtypes: float64(6)
# memory usage: 41.3+ KB

# %%
df=df.drop(df.index[0])
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close  \
# Date
# 2020-01-03  29.366667  30.266666  29.128000  29.534000  29.534000
# 2020-01-06  29.364668  30.104000  29.333332  30.102667  30.102667
# 2020-01-07  30.760000  31.441999  30.224001  31.270666  31.270666
# 2020-01-08  31.580000  33.232666  31.215334  32.809334  32.809334
# 2020-01-09  33.139999  33.253334  31.524668  32.089333  32.089333
#
#             Retornos simples
# Date
# 2020-01-03          0.029633
# 2020-01-06          0.019255
# 2020-01-07          0.038801
# 2020-01-08          0.049205
# 2020-01-09         -0.021945

# %% [markdown]
# b) Grafique la serie de tiempo de los retornos simples y obtenga:
# - El retorno simple más alto,
# - El retorno simple más bajo,
# - Las fechas en que ocurrieron.

# %% [markdown]
# c) Obtenga el histograma de frecuencia de la serie de retornos simples.
# ¿Estos se distribuyen normalmente? Justifique su respuesta calculando el coeficiente de asimetría, kurtosis y haciendo la prueba de Shapiro–Wilk

# %% [markdown]
# d) Genere las gráficas de caja por año de los precios de cierre.

# %%
#b) Grafique la serie de tiempo de los retornos simples
#grafica de serie temporal
plt.figure(figsize=(20,10), dpi =150)
plt.plot(df.index,df['Retornos simples'], lw = 1, color='blue')
plt.title('Retorno simple', fontsize=25)
plt.ylabel('Precio de cierre', fontdict= {'fontsize':25})
plt.xlabel('Fecha', fontdict= {'fontsize':25})
plt.grid(False)

# %%
#El retorno simple más alto,
#El retorno simple más bajo,
#Las fechas en que ocurrieron.

print("Máximo:", df.idxmax(), df.max())
# Out:
# Máximo: Open                2021-11-04
# High                2021-11-04
# Low                 2021-11-04
# Close               2021-11-04
# Adj Close           2021-11-04
# Retornos simples    2020-02-03
# dtype: object Open                411.470001
# High                414.496674
# Low                 405.666656
# Close               409.970001
# Adj Close           409.970001
# Retornos simples      0.198949
# dtype: float64

# %% [markdown]
# el retorno máximo ocurrio en 2020-02-03 con un valor de 0.198949

# %%
print("Mínimo:", df.idxmin(), df.min())
# Out:
# Mínimo: Open                2020-03-19
# High                2020-03-18
# Low                 2020-03-18
# Close               2020-03-18
# Adj Close           2020-03-18
# Retornos simples    2020-09-08
# dtype: object Open                24.980000
# High                26.990667
# Low                 23.367332
# Close               24.081333
# Adj Close           24.081333
# Retornos simples    -0.210628
# dtype: float64

# %% [markdown]
# el retorno minimo ocurrio 2020-09-08 con un valor de -0.210628

# %% [markdown]
# ***c) Obtenga el histograma de frecuencia de la serie de retornos simples.***

# %%
#grafica del histograma de la serie de retornos simples

plt.figure(figsize=(5,4))
plt.hist(df['Retornos simples'], bins=19, color='purple', edgecolor='green')
plt.title('Histograma del conteo de retornos simples')
plt.xlabel('Retornos simples')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ¿Estos se distribuyen normalmente? Justifique su respuesta calculando el coeficiente de asimetría, kurtosis y haciendo la prueba de Shapiro–Wilk.

# %%
resumen = pd.DataFrame({
    'Mínimo': df.min(),
    'Q1': df.quantile(0.25),
    'Mediana': df.median(),
    'Q3': df.quantile(0.75),
    'Máximo': df.max(),
    'Asimetría': df.skew(),
    'Curtosis': df.kurt()
})
resumen
# Out:
#                      Mínimo          Q1     Mediana          Q3      Máximo  \
# Open              24.980000  138.741669  224.000000  278.460007  411.470001
# High              26.990667  142.261665  229.330002  283.491669  414.496674
# Low               23.367332  135.626670  218.199997  270.511658  405.666656
# Close             24.081333  138.703331  223.656662  276.763337  409.970001
# Adj Close         24.081333  138.703331  223.656662  276.763337  409.970001
# Retornos simples  -0.210628   -0.021480    0.001953    0.024981    0.198949
#
#                   Asimetría  Curtosis
# Open              -0.298055 -0.787892
# High              -0.293179 -0.782198
# Low               -0.306408 -0.804483
# Close             -0.300317 -0.789155
# Adj Close         -0.300317 -0.789155
# Retornos simples   0.086197  2.745629

# %% [markdown]
# El coeficiente de asimetría de Fisher es un coeficiente que permite calcular la asimetría de una distribución. Es decir, el coeficiente de asimetría sirve para determinar si una función es asimétrica positiva, asimétrica negativa o simétrica.( el comando para calcularlo es .skew) Si el coeficiente de Fisher es mayor a 0 la distribución es asimétrica positiva. Si el coeficiente de Fisher es menor a 0 la distribución es asimétrica negativa.
#
# Para Open, High, Low, Close y Adj Close podemos concluir que su distribución es asimétrica negativa. Mientras que para Retornos simples la distribución es asimétrica positiva.
#
# La curtosis (Kurtosis) define en qué grado las colas de la distribución difieren de las colas de una distribución normal.(.kurt)
#
# Para Open, High, Low, Close y Adj Close podemos concluir que la distribución es platicúrtica (distribución con colas menos largas que la normal). Mientras que para Retornos simples la distribución es la distribución es leptocúrtica (distribución con colas más largas que la normal).

# %%
#PRUEBA DE Shapiro-Wilk
from scipy.stats import shapiro

# %%
columnas = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Retornos simples']

for col in columnas:
    estadistico, p_value = shapiro(df[col])
    print(f'{col}:  Estadístico = {estadistico:.3f}, p-value = {p_value:.10f}\n')
# Out:
# Open:  Estadístico = 0.955, p-value = 0.0000000000
#
# High:  Estadístico = 0.955, p-value = 0.0000000000
#
# Low:  Estadístico = 0.955, p-value = 0.0000000000
#
# Close:  Estadístico = 0.955, p-value = 0.0000000000
#
# Adj Close:  Estadístico = 0.955, p-value = 0.0000000000
#
# Retornos simples:  Estadístico = 0.964, p-value = 0.0000000000

# %%
Un valor  p<0.05 , indica evidencia suficiente contra la normalidad de los datos, sugiriendo que se rechace  H0 . Y como el  p  obtenido en los datos es menor a  0.05 , por tanto no se distribuyen los datos normalmente.

# %% [markdown]
# d) Genere las gráficas de caja por año de los precios de cierre.

# %%
plt.figure(figsize=(5,4))
plt.boxplot(df['Close'], vert = False, patch_artist=True ) # para detectar datos atipicos
plt.title('Boxplot Close')
plt.show()

# %%
plt.figure(figsize=(10,6), dpi=150)
plt.boxplot(df, labels=df.columns)
plt.title('Boxplot ')
plt.show()
# Out:
# /tmp/ipython-input-152-96201278.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(df, labels=df.columns)

# %% [markdown]
# Ejercicio 5.
#
# Guarde en un DataFrame los datos de los 6 contaminantes principales de la ciudad de Puebla a partir del año 2016 (contam_PUE_ugm3.csv en GitHub). A continuación, realice lo siguiente:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

Rutap='https://raw.githubusercontent.com/jamc88/AD-MCMAI/refs/heads/main/Datos/contam_PUE_ugm3.csv'
contam = pd.read_csv(Rutap, parse_dates = True, index_col=0)
contam.head()
# Out:
#                   O3       PM10       PM25       SO2        CO       NO2
# Fecha
# 2016-01-01  0.028414  44.694444  28.097222  0.003244  1.763388  0.020635
# 2016-01-02  0.027376  31.527778  13.791667  0.003339  1.796858  0.022468
# 2016-01-03  0.032512  44.333333  20.430556  0.003551  1.845788  0.023123
# 2016-01-04  0.028332  24.990338   9.569444  0.003051  1.756417  0.020897
# 2016-01-05  0.026939  21.763889  10.638889  0.003296  1.782832  0.021215

# %%
contam.columns =['O3', 'PM10', 'PM25', 'SO2', 'CO', 'NO2']

# %%
contam.describe()
# Out:
#                 O3         PM10         PM25          SO2           CO  \
# count  3043.000000  3043.000000  3043.000000  3043.000000  3043.000000
# mean      0.044932    41.575854    17.122126     0.003486     1.195836
# std       0.013539    15.498889     7.403356     0.001189     0.398137
# min       0.014422     5.739899     1.666667     0.000856     0.326635
# 25%       0.035606    30.194444    11.781840     0.002627     0.931935
# 50%       0.042851    39.930556    15.692633     0.003374     1.114111
# 75%       0.051064    51.951389    21.654891     0.004087     1.370332
# max       0.103337   109.680556    59.158432     0.010058     2.932127
#
#                NO2
# count  3043.000000
# mean      0.025427
# std       0.007780
# min       0.007823
# 25%       0.020079
# 50%       0.024406
# 75%       0.030052
# max       0.059077

# %% [markdown]
# a) Obtenga las gráficas de series de tiempo** de todos los contaminantes, los gráficos de caja, y calcule el número de datos atípicos de cada uno.

# %%
contam.plot(subplots=True)
plt.show()

# %%
plt.figure(figsize=(5,4))
plt.boxplot(contam['O3'],
            vert = False,
            patch_artist=True) # vert = False,
plt.show()

# %%
plt.figure(figsize=(5,4))
plt.boxplot(contam['PM10'],
            vert = False,
            patch_artist=True) # vert = False,
plt.show()

# %%
plt.figure(figsize=(5,4))
plt.boxplot(contam['PM25'],
            vert = False,
            patch_artist=True) # vert = False,
plt.show()

# %%
plt.figure(figsize=(5,4))
plt.boxplot(contam['SO2'],
            vert = False,
            patch_artist=True) # vert = False,
plt.show()

# %%
plt.figure(figsize=(5,4))
plt.boxplot(contam['CO'],
            vert = False,
            patch_artist=True) # vert = False,
plt.show()

# %%
plt.figure(figsize=(5,4))
plt.boxplot(contam['NO2'],
            vert = False,
            patch_artist=True) # vert = False,
plt.show()

# %%
df.columns = df.columns.str.strip()

# %%
def contar_outliers_serie(serie):
    Q1 = serie.quantile(0.25)
    Q3 = serie.quantile(0.75)
    IQR = Q3 - Q1
    lim_inf = Q1 - 1.5 * IQR
    lim_sup = Q3 + 1.5 * IQR
    return ((serie < lim_inf) | (serie > lim_sup)).sum()

# Aplica a todas las columnas de contaminantes

outliers_por_columna = {col: contar_outliers_serie(df[col]) for col in contam}

print("Número de datos atípicos por contaminante:")
for contaminante, cantidad in outliers_por_columna.items():
    print(f"{contaminante}: {cantidad}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'O3'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-140-549704726.py in <cell line: 0>()
#       9 # Aplica a todas las columnas de contaminantes
#      10
# ...

# %% [markdown]
# b) Realice una prueba de contraste de normalidad para los datos. Obtenga una matriz de correlación y un mapa de calor de los contaminantes utilizando el coeficiente de correlación apropiado.

# %%
from scipy.stats import shapiro

# %%
columnas=['O3', 'PM10', 'PM25', 'SO2', 'CO', 'NO2']
for col in columnas:
    estadistico, p_value = shapiro(contam[col])
    print(f'{col}:  Estadístico = {estadistico:.3f}, p-value = {p_value:.10f}\n')
# Out:
# O3:  Estadístico = 0.948, p-value = 0.0000000000
#
# PM10:  Estadístico = 0.978, p-value = 0.0000000000
#
# PM25:  Estadístico = 0.947, p-value = 0.0000000000
#
# SO2:  Estadístico = 0.952, p-value = 0.0000000000
#
# CO:  Estadístico = 0.940, p-value = 0.0000000000
#
# NO2:  Estadístico = 0.973, p-value = 0.0000000000

# %% [markdown]
# Todos los valores de $p$  en los datos de los contaminantes son menores que $0$ por tanto podemos decir que no se distribuyen normalmente.

# %% [markdown]
# c) Obtenga un DataFrame que muestre la correlación 2 a 2 entre los contaminantes.
# Grafique 3 diagramas de dispersión** entre los contaminantes que presentan mayor correlación, ya sea positiva o negativa.

# %%
corr_mat=contam.corr(method='spearman')
corr_mat
# Out:
#             O3      PM10      PM25       SO2        CO       NO2
# O3    1.000000  0.153624  0.222908  0.181364 -0.140142  0.152639
# PM10  0.153624  1.000000  0.801181  0.184809  0.077875  0.295981
# PM25  0.222908  0.801181  1.000000  0.144050 -0.010204  0.315743
# SO2   0.181364  0.184809  0.144050  1.000000  0.133664  0.340807
# CO   -0.140142  0.077875 -0.010204  0.133664  1.000000 -0.007370
# NO2   0.152639  0.295981  0.315743  0.340807 -0.007370  1.000000

# %%
plt.figure(figsize=(8, 6),dpi=150)
sns.heatmap(corr_mat, annot=True,
            cmap='summer',
            linewidths=0.2,
            cbar_kws={'label': 'Coeficiente de Spearman'},
           vmin = 0, vmax = 1, center = 0.5)
plt.title('Matriz de Correlación', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
pip install pingouin # sirve para instalar paqueterias
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.4/204.4 kB 7.9 MB/s eta 0:00:00
# ...

# %%
import pingouin as pg

# %%
#muestra la correlación 2 a 2 entre los contaminantes
corr=pg.pairwise_corr(contam, method='spearman')
corr
# Out:
#        X     Y    method alternative     n         r           CI95%  \
# 0     O3  PM10  spearman   two-sided  3043  0.153624    [0.12, 0.19]
# 1     O3  PM25  spearman   two-sided  3043  0.222908    [0.19, 0.26]
# 2     O3   SO2  spearman   two-sided  3043  0.181364    [0.15, 0.22]
# 3     O3    CO  spearman   two-sided  3043 -0.140142  [-0.17, -0.11]
# 4     O3   NO2  spearman   two-sided  3043  0.152639    [0.12, 0.19]
# 5   PM10  PM25  spearman   two-sided  3043  0.801181    [0.79, 0.81]
# 6   PM10   SO2  spearman   two-sided  3043  0.184809    [0.15, 0.22]
# 7   PM10    CO  spearman   two-sided  3043  0.077875    [0.04, 0.11]
# 8   PM10   NO2  spearman   two-sided  3043  0.295981    [0.26, 0.33]
# 9   PM25   SO2  spearman   two-sided  3043  0.144050    [0.11, 0.18]
# 10  PM25    CO  spearman   two-sided  3043 -0.010204   [-0.05, 0.03]
# 11  PM25   NO2  spearman   two-sided  3043  0.315743    [0.28, 0.35]
# 12   SO2    CO  spearman   two-sided  3043  0.133664     [0.1, 0.17]
# ...

# %%
corr.sort_values(by=['r'], ascending=False)[['X', 'Y', 'r']].round(3)
# Out:
#        X     Y      r
# 5   PM10  PM25  0.801
# 13   SO2   NO2  0.341
# 11  PM25   NO2  0.316
# 8   PM10   NO2  0.296
# 1     O3  PM25  0.223
# 6   PM10   SO2  0.185
# 2     O3   SO2  0.181
# 0     O3  PM10  0.154
# 4     O3   NO2  0.153
# 9   PM25   SO2  0.144
# 12   SO2    CO  0.134
# 7   PM10    CO  0.078
# 14    CO   NO2 -0.007
# 10  PM25    CO -0.010
# 3     O3    CO -0.140

# %%
sns.scatterplot(data=contam, x='PM10', y='PM25')
plt.grid(True)
plt.show()

# %%
sns.scatterplot(data=contam, x='SO2', y='NO2')
plt.grid(True)
plt.show()

# %%
sns.scatterplot(data=contam, x='PM25', y='NO2')
plt.grid(True)
plt.show()

# %% [markdown]
# d) Aplique el test de Mann-Kendall a todos los contaminantes y obtenga una gráfica con la línea de tendencia de cada uno (en caso de que exista).

# %%
# !pip install pymannkendall

# %%
import pymannkendall as mk

# %%
resultado1=mk.original_test(contam['O3'],alpha=0.05)
resultado1
# Out:
# Mann_Kendall_Test(trend='increasing', h=np.True_, p=np.float64(0.0), z=np.float64(17.591507915746828), Tau=np.float64(0.21272110488218074), s=np.float64(984559.0), var_s=np.float64(3132394657.6666665), slope=np.float64(4.097957091780723e-06), intercept=np.float64(0.036618215678404814))

# %%
resultado2=mk.original_test(contam['PM10'],alpha=0.05)
resultado2
# Out:
# Mann_Kendall_Test(trend='decreasing', h=np.True_, p=np.float64(6.661338147750939e-15), z=np.float64(-7.7914418728468355), Tau=np.float64(-0.09421629879679881), s=np.float64(-436071.0), var_s=np.float64(3132396641.6666665), slope=np.float64(-0.0025048446024340293), intercept=np.float64(43.740424195857706))

# %%
resultado3=mk.original_test(contam['PM25'],alpha=0.05)
resultado3
# Out:
# Mann_Kendall_Test(trend='decreasing', h=np.True_, p=np.float64(0.01117620157945054), z=np.float64(-2.537140732486618), Tau=np.float64(-0.030679912704230813), s=np.float64(-141999.0), var_s=np.float64(3132386471.0), slope=np.float64(-0.0003692726766993715), intercept=np.float64(16.254296591501287))

# %%
resultado4=mk.original_test(contam['SO2'],alpha=0.05)
resultado4
# Out:
# Mann_Kendall_Test(trend='increasing', h=np.True_, p=np.float64(0.0), z=np.float64(15.533965649282166), Tau=np.float64(0.18784081680009282), s=np.float64(869403.0), var_s=np.float64(3132395482.3333335), slope=np.float64(3.6216698450634786e-07), intercept=np.float64(0.0028233345947905448))

# %%
resultado5=mk.original_test(contam['CO'],alpha=0.05)
resultado5
# Out:
# Mann_Kendall_Test(trend='decreasing', h=np.True_, p=np.float64(0.0), z=np.float64(-18.73453024620918), Tau=np.float64(-0.22653321242769914), s=np.float64(-1048487.0), var_s=np.float64(3132129109.6666665), slope=np.float64(-0.00013034442788541125), intercept=np.float64(1.3123647582381186))

# %%
resultado6=mk.original_test(contam['NO2'],alpha=0.05)
resultado6
# Out:
# Mann_Kendall_Test(trend='increasing', h=np.True_, p=np.float64(0.0), z=np.float64(17.235795094562977), Tau=np.float64(0.208419621195475), s=np.float64(964650.0), var_s=np.float64(3132391177.3333335), slope=np.float64(2.8175689112537964e-06), intercept=np.float64(0.020120591073960775))

# %%
contam.columns
# Out:
# Index(['O3', 'PM10', 'PM25', 'SO2', 'CO', 'NO2'], dtype='object')

# %%
for val in resultado: print(val)
# Out:
# increasing
# True
# 0.0
# 17.591507915746828
# 0.21272110488218074
# 984559.0
# 3132394657.6666665
# 4.097957091780723e-06
# 0.036618215678404814

# %%
for val in contam:
  resultado=mk.original_test(contam[val],alpha=0.05)
  print(val)
  for val in resultado: print(val)
  print('\n')
# Out:
# O3
# increasing
# True
# 0.0
# 17.591507915746828
# 0.21272110488218074
# 984559.0
# 3132394657.6666665
# 4.097957091780723e-06
# 0.036618215678404814
#
#
# PM10
# decreasing
# True
# 6.661338147750939e-15
# -7.7914418728468355
# -0.09421629879679881
# -436071.0
# 3132396641.6666665
# -0.0025048446024340293
# 43.740424195857706
#
#
# PM25
# decreasing
# True
# 0.01117620157945054
# -2.537140732486618
# -0.030679912704230813
# -141999.0
# 3132386471.0
# -0.0003692726766993715
# 16.254296591501287
#
#
# SO2
# increasing
# True
# 0.0
# 15.533965649282166
# 0.18784081680009282
# 869403.0
# 3132395482.3333335
# 3.6216698450634786e-07
# 0.0028233345947905448
#
#
# CO
# decreasing
# True
# 0.0
# -18.73453024620918
# -0.22653321242769914
# -1048487.0
# 3132129109.6666665
# -0.00013034442788541125
# 1.3123647582381186
#
#
# NO2
# increasing
# True
# 0.0
# 17.235795094562977
# 0.208419621195475
# 964650.0
# 3132391177.3333335
# 2.8175689112537964e-06
# 0.020120591073960775

# %%
slope = mk.original_test(contam['O3'], alpha = 0.05).slope
intercept = mk.original_test(contam['O3'], alpha = 0.05).intercept

linea = []
for i in range(0, len(contam)):
    linea.append(slope*i+intercept)

linea = pd.DataFrame(linea,index = contam.index)

# %%
plt.figure(figsize=(15,7), dpi=100)
plt.plot(contam['O3'],lw=1, color='pink')
plt.plot(linea,lw=3, color='purple')
plt.tick_params(labelsize=20)
plt.grid(True)

# %%
slope = mk.original_test(contam['PM10'], alpha = 0.05).slope
intercept = mk.original_test(contam['PM10'], alpha = 0.05).intercept

linea = []
for i in range(0, len(contam)):
    linea.append(slope*i+intercept)

linea = pd.DataFrame(linea,index = contam.index)

# %%
plt.figure(figsize=(15,7), dpi=100)
plt.plot(contam['PM10'],lw=1, color='pink')
plt.plot(linea,lw=3, color='purple')
plt.tick_params(labelsize=20)
plt.grid(True)

# %%
slope = mk.original_test(contam['PM25'], alpha = 0.05).slope
intercept = mk.original_test(contam['PM25'], alpha = 0.05).intercept

linea = []
for i in range(0, len(contam)):
    linea.append(slope*i+intercept)

linea = pd.DataFrame(linea,index = contam.index)

# %%
plt.figure(figsize=(15,7), dpi=100)
plt.plot(contam['PM25'],lw=1, color='pink')
plt.plot(linea,lw=3, color='purple')
plt.tick_params(labelsize=20)
plt.grid(True)

# %%
slope = mk.original_test(contam['SO2'], alpha = 0.05).slope
intercept = mk.original_test(contam['SO2'], alpha = 0.05).intercept

linea = []
for i in range(0, len(contam)):
    linea.append(slope*i+intercept)

linea = pd.DataFrame(linea,index = contam.index)

# %%
plt.figure(figsize=(15,7), dpi=100)
plt.plot(contam['SO2'],lw=1, color='pink')
plt.plot(linea,lw=3, color='purple')
plt.tick_params(labelsize=20)
plt.grid(True)

# %%
plt.figure(figsize=(15,7), dpi=100)
plt.plot(contam['CO'],lw=1, color='pink')
plt.plot(linea,lw=3, color='purple')
plt.tick_params(labelsize=20)
plt.grid(True)

# %%
slope = mk.original_test(contam['NO2'], alpha = 0.05).slope
intercept = mk.original_test(contam['NO2'], alpha = 0.05).intercept

linea = []
for i in range(0, len(contam)):
    linea.append(slope*i+intercept)

linea = pd.DataFrame(linea,index = contam.index)

# %%
plt.figure(figsize=(15,7), dpi=100)
plt.plot(contam['NO2'],lw=1, color='pink')
plt.plot(linea,lw=3, color='purple')
plt.tick_params(labelsize=20)
plt.grid(True)

# %% [markdown]
# e) Compruebe la existencia de tendencia mediante el método ITA (Innovative Trend Analysis)

# %%
int(len(contam)/2)
# Out:
# 1521

# %%
p1=contam['O3'].iloc[0:int(len(contam)/2)]
p2=contam['O3'].iloc[int(len(contam)/2):2*int(len(contam)/2)]

# %%
fig = plt.figure(figsize=(5,5), dpi=100)
plt.scatter(sorted(p1),sorted(p2), s=40, color='red',alpha=0.5)
plt.tick_params(labelsize=15)

# %%
fig = plt.figure(figsize=(5,5), dpi=100)
plt.scatter(sorted(p1),sorted(p2), s=40, color='red', alpha=0.5);
plt.tick_params(labelsize=15)

x_min = 0
x_max = 0.10
x_vals = np.linspace(x_min, x_max, 100)

plt.plot(x_vals, x_vals, color='black')
plt.show()

# %%
p11=contam['PM10'].iloc[0:int(len(contam)/2)]
p21=contam['PM10'].iloc[int(len(contam)/2):2*int(len(contam)/2)]

# %%
fig = plt.figure(figsize=(5,5), dpi=100)
plt.scatter(sorted(p11),sorted(p21), s=40, color='red',alpha=0.5)
plt.tick_params(labelsize=15)

# %%
fig = plt.figure(figsize=(5,5), dpi=100)
plt.scatter(sorted(p11),sorted(p21), s=40, color='red', alpha=0.5);
plt.tick_params(labelsize=15)

x_min = 0
x_max = 100
x_vals = np.linspace(x_min, x_max, 100)

plt.plot(x_vals, x_vals, color='black')
plt.show()

# %%
p12=contam['PM25'].iloc[0:int(len(contam)/2)]
p22=contam['PM25'].iloc[int(len(contam)/2):2*int(len(contam)/2)]

# %%
fig = plt.figure(figsize=(5,5), dpi=100)
plt.scatter(sorted(p12),sorted(p22), s=40, color='red',alpha=0.5)
plt.tick_params(labelsize=15)

# %%
fig = plt.figure(figsize=(5,5), dpi=100)
plt.scatter(sorted(p12),sorted(p22), s=40, color='red', alpha=0.5);
plt.tick_params(labelsize=15)

x_min = 0
x_max = 60
x_vals = np.linspace(x_min, x_max, 100)

plt.plot(x_vals, x_vals, color='black')
plt.show()

# %%
p13=contam['SO2'].iloc[0:int(len(contam)/2)]
p23=contam['SO2'].iloc[int(len(contam)/2):2*int(len(contam)/2)]

# %%
fig = plt.figure(figsize=(5,5), dpi=100)
plt.scatter(sorted(p13),sorted(p23), s=40, color='red',alpha=0.5)
plt.tick_params(labelsize=15)

# %%
fig = plt.figure(figsize=(5,5), dpi=100)
plt.scatter(sorted(p13),sorted(p23), s=40, color='red', alpha=0.5);
plt.tick_params(labelsize=15)

x_min = 0
x_max = 0.008
x_vals = np.linspace(x_min, x_max, 100)

plt.plot(x_vals, x_vals, color='black')
plt.show()

# %%
p14=contam['CO'].iloc[0:int(len(contam)/2)]
p24=contam['CO'].iloc[int(len(contam)/2):2*int(len(contam)/2)]

# %%
fig = plt.figure(figsize=(5,5), dpi=100)
plt.scatter(sorted(p14),sorted(p24), s=40, color='red',alpha=0.5)
plt.tick_params(labelsize=15)

# %%
fig = plt.figure(figsize=(5,5), dpi=100)
plt.scatter(sorted(p14),sorted(p24), s=40, color='red', alpha=0.5);
plt.tick_params(labelsize=15)

x_min = 0
x_max = 3
x_vals = np.linspace(x_min, x_max, 100)

plt.plot(x_vals, x_vals, color='black')
plt.show()

# %%
p15=contam['NO2'].iloc[0:int(len(contam)/2)]
p25=contam['NO2'].iloc[int(len(contam)/2):2*int(len(contam)/2)]

# %%
fig = plt.figure(figsize=(5,5), dpi=100)
plt.scatter(sorted(p15),sorted(p25), s=40, color='red',alpha=0.5)
plt.tick_params(labelsize=15)

# %%
fig = plt.figure(figsize=(5,5), dpi=100)
plt.scatter(sorted(p1),sorted(p2), s=40, color='red', alpha=0.5);
plt.tick_params(labelsize=15)

x_min = 0
x_max = 0.1
x_vals = np.linspace(x_min, x_max, 100)

plt.plot(x_vals, x_vals, color='black')
plt.show()
